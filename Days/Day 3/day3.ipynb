# %% [markdown]
# --- Day 3: Gear Ratios ---
#
# You and the Elf eventually reach a gondola lift station; he says the gondola lift will take you up to the water source, but this is as far as he can bring you. You go inside.
#
# It doesn't take long to find the gondolas, but there seems to be a problem: they're not moving.
#
# "Aaah!"
#
# You turn around to see a slightly-greasy Elf with a wrench and a look of surprise. "Sorry, I wasn't expecting anyone! The gondola lift isn't working right now; it'll still be a while before I can fix it." You offer to help.
#
# The engineer explains that an engine part seems to be missing from the engine, but nobody can figure out which one. If you can add up all the part numbers in the engine schematic, it should be easy to work out which part is missing.
#
# The engine schematic (your puzzle input) consists of a visual representation of the engine. There are lots of numbers and symbols you don't really understand, but apparently any number adjacent to a symbol, even diagonally, is a "part number" and should be included in your sum. (Periods (.) do not count as a symbol.)
#
# Here is an example engine schematic:
#
# ```
# 467..114..
# ...*......
# ..35..633.
# ......#...
# 617*......
# .....+.58.
# ..592.....
# ......755.
# ...$.*....
# .664.598..
# ```
#
# In this schematic, two numbers are not part numbers because they are not adjacent to a symbol: 114 (top right) and 58 (middle right). Every other number is adjacent to a symbol and so is a part number; their sum is 4361.
#
# Of course, the actual engine schematic is much larger. What is the sum of all of the part numbers in the engine schematic?

# %%
with open("input.txt","r") as f:
    lines = f.readlines()

# %%
test_lines = [
"467..114..",
"...*......",
"..35..633.",
"......#...",
"617*......",
".....+.58.",
"..592.....",
"......755.",
"...$.*....",
".664.598..",
]

# %%
def is_symbol(char):
    return char in [ '#','$','%','&','*','+','-','/','=','@']

# %%
grid = []
for line in lines:
    row = []
    for elem in line:
        row.append(elem)
    grid.append(row)

grid_matches = []

for i in range(len(grid)):
    for j in range(len (grid[0])):
        if grid[i][j].isdigit():
            flag=0
            row_above = i-1
            row_below = i + 1
            col_left = j -1
            col_right = j+1
            matches=[]
            if row_above >=0:
                if col_left>=0:
                    if is_symbol(grid[row_above][col_left]):
                        flag = 1
                if is_symbol(grid[row_above][j]):
                    flag = 1
                if col_right <= len(grid[0]):
                    if is_symbol(grid[row_above][col_right]):
                        flag=1
            if col_left>=0:
                if is_symbol(grid[i][col_left]):
                    flag = 1
            if col_right <= len(grid[0]):
                if is_symbol(grid[i][col_right]):
                    flag=1

            if row_below <=len(grid)-1:
                if col_left>=0:
                    if is_symbol(grid[row_below][col_left]):
                        flag = 1
                if is_symbol(grid[row_below][j]):
                    flag = 1
                if col_right <= len(grid[0]):
                    if is_symbol(grid[row_below][col_right]):
                        flag=1
            if flag:
                grid_matches.append((i,j))

grid_matches
# Out:
# [(0, 25),
#  (0, 26),
#  (0, 50),
#  (0, 78),
#  (0, 79),
#  (0, 99),
#  (0, 100),
#  (0, 104),
#  (0, 106),
#  (0, 127),
#  (0, 128),
#  (1, 62),
#  (1, 68),
#  (1, 69),
#  (1, 120),
#  (1, 121),
#  (1, 122),
#  (1, 133),
#  (2, 4),
#  (2, 10),
#  (2, 11),
#  (2, 37),
#  (2, 38),
#  (2, 39),
#  (2, 77),
#  (2, 80),
#  (2, 81),
#  (2, 90),
#  (2, 91),
#  (2, 92),
#  (2, 99),
#  (2, 100),
#  (2, 108),
#  (2, 114),
#  (2, 115),
#  (2, 131),
#  (3, 21),
#  (3, 27),
#  (3, 44),
#  (3, 51),
#  (3, 52),
#  (3, 57),
#  (3, 58),
#  (3, 67),
#  (3, 68),
#  (3, 85),
#  (3, 106),
#  (3, 122),
#  (3, 135),
#  (3, 137),
#  (4, 4),
#  (4, 9),
#  (4, 12),
#  (4, 75),
#  (4, 117),
#  (5, 19),
#  (5, 20),
#  (5, 21),
#  (5, 25),
#  (5, 50),
#  (5, 51),
#  (5, 83),
#  (5, 84),
#  (5, 102),
#  (5, 129),
#  (5, 131),
#  (6, 32),
#  (6, 56),
#  (6, 104),
#  (6, 117),
#  (6, 118),
#  (6, 136),
#  (7, 11),
#  (7, 19),
#  (7, 20),
#  (7, 21),
#  (7, 54),
#  (7, 71),
#  (7, 72),
#  (7, 89),
#  (7, 95),
# ...

# %%
pattern = r'([0-9])+'
import re
total=0

for row_num, line in enumerate(lines):
    matches = re.finditer(pattern, line)
    for groupNum,match_obj in enumerate(matches):
        flag = 0
        curr_gear_matches = []
        for grid_match in grid_matches:
            if (grid_match[0]==row_num) and(grid_match[1]>=match_obj.start()) and (grid_match[1]<=match_obj.end()):
                flag = 1

        if flag:

            total += int(match_obj.group())
total
# Out:
# 529618
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# --- Part Two ---
#
# The engineer finds the missing part and installs it in the engine! As the engine springs to life, you jump in the closest gondola, finally ready to ascend to the water source.
#
# You don't seem to be going very fast, though. Maybe something is still wrong? Fortunately, the gondola has a phone labeled "help", so you pick it up and the engineer answers.
#
# Before you can explain the situation, she suggests that you look out the window. There stands the engineer, holding a phone in one hand and waving with the other. You're going so slowly that you haven't even left the station. You exit the gondola.
#
# The missing part wasn't the only issue - one of the gears in the engine is wrong. A gear is any * symbol that is adjacent to exactly two part numbers. Its gear ratio is the result of multiplying those two numbers together.
#
# This time, you need to find the gear ratio of every gear and add them all up so that the engineer can figure out which gear needs to be replaced.
#
# Consider the same engine schematic again:
#
# ```
# 467..114..
# ...*......
# ..35..633.
# ......#...
# 617*......
# .....+.58.
# ..592.....
# ......755.
# ...$.*....
# .664.598..
# ```
#
# In this schematic, there are two gears. The first is in the top left; it has part numbers 467 and 35, so its gear ratio is 16345. The second gear is in the lower right; its gear ratio is 451490. (The * adjacent to 617 is not a gear because it is only adjacent to one part number.) Adding up all of the gear ratios produces 467835.
#
# What is the sum of all of the gear ratios in your engine schematic?

# %%
def is_star(char):
    return char in ['*']

# %%
grid = []
for line in lines:
    row = []
    for elem in line:
        row.append(elem)
    grid.append(row)

grid_matches = []

for i in range(len(grid)):
    for j in range(len (grid[0])):
        if grid[i][j].isdigit():
            flag=0
            row_above = i-1
            row_below = i + 1
            col_left = j -1
            col_right = j+1
            matches=[]
            if row_above >=0:
                if col_left>=0:
                    if is_star(grid[row_above][col_left]):
                        flag = 1
                        matches.append((row_above,col_left))
                if is_star(grid[row_above][j]):
                    flag = 1
                    matches.append((row_above,j))
                if col_right <= len(grid[0]):
                    if is_star(grid[row_above][col_right]):
                        flag=1
                        matches.append((row_above,col_right))
            if col_left>=0:
                if is_star(grid[i][col_left]):
                    flag = 1
                    matches.append((i,col_left))
            if col_right <= len(grid[0]):
                if is_star(grid[i][col_right]):
                    flag=1
                    matches.append((i,col_right))

            if row_below <=len(grid)-1:
                if col_left>=0:
                    if is_star(grid[row_below][col_left]):
                        flag = 1
                        matches.append((row_below,col_left))
                if is_star(grid[row_below][j]):
                    flag = 1
                    matches.append((row_below,j))
                if col_right <= len(grid[0]):
                    if is_star(grid[row_below][col_right]):
                        flag=1
                        matches.append((row_below,col_right))
            if flag:
                grid_matches.append(((i,j),matches))

grid_matches
# Out:
# [((0, 78), [(1, 78)]),
#  ((0, 79), [(1, 78)]),
#  ((0, 99), [(1, 99)]),
#  ((0, 100), [(1, 99)]),
#  ((0, 104), [(1, 105)]),
#  ((0, 106), [(1, 105)]),
#  ((1, 68), [(2, 68)]),
#  ((1, 69), [(2, 68)]),
#  ((1, 120), [(2, 121)]),
#  ((1, 121), [(2, 121)]),
#  ((1, 122), [(2, 121)]),
#  ((1, 133), [(2, 132)]),
#  ((2, 4), [(3, 5)]),
#  ((2, 10), [(3, 10)]),
#  ((2, 11), [(3, 10)]),
#  ((2, 77), [(1, 78)]),
#  ((2, 99), [(1, 99)]),
#  ((2, 100), [(1, 99)]),
#  ((2, 108), [(3, 107)]),
#  ((2, 131), [(2, 132)]),
#  ((3, 51), [(4, 51)]),
#  ((3, 52), [(4, 51)]),
#  ((3, 67), [(2, 68)]),
#  ((3, 68), [(2, 68)]),
#  ((3, 85), [(4, 84)]),
#  ((3, 106), [(3, 107)]),
#  ((3, 122), [(2, 121)]),
#  ((3, 135), [(4, 136)]),
#  ((3, 137), [(4, 136)]),
#  ((4, 4), [(3, 5)]),
#  ((4, 9), [(3, 10)]),
#  ((4, 117), [(5, 118)]),
#  ((5, 19), [(6, 20)]),
#  ((5, 20), [(6, 20)]),
#  ((5, 21), [(6, 20)]),
#  ((5, 50), [(4, 51)]),
#  ((5, 51), [(4, 51)]),
#  ((5, 83), [(4, 84)]),
#  ((5, 84), [(4, 84)]),
# ...

# %%
pattern = r'([0-9])+'
import re
total=0
gear_dict = {}
for row_num, line in enumerate(lines):
    matches = re.finditer(pattern, line)
    for groupNum,match_obj in enumerate(matches):
        flag = 0
        curr_gear_matches = []
        for grid_match,gear_match in grid_matches:
            if (grid_match[0]==row_num) and(grid_match[1]>=match_obj.start()) and (grid_match[1]<=match_obj.end()):
                if flag==0:
                    for gear_match_tup in gear_match:
                        curr_gear_matches.append(gear_match_tup)
                flag = 1
        if flag:
            for curr_gear_match in curr_gear_matches:
                curr_gear_list = gear_dict.get(f"{curr_gear_match[0]}_{curr_gear_match[1]}",[]) 
                curr_gear_list.append(int(match_obj.group()))
                gear_dict[f"{curr_gear_match[0]}_{curr_gear_match[1]}"] = curr_gear_list
            #total += int(match_obj.group())\
total=0
for key in gear_dict.keys():
    curr_gear = gear_dict[key]
    if len(curr_gear)==2:
        total += curr_gear[0]*curr_gear[1]
total
# Out:
# 77509019
